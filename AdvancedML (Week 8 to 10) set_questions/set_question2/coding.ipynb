# %%
# 1.
from sklearn.datasets import load_wine
import pandas as pd

X, y = load_wine(return_X_y=True, as_frame=True)

# Perform Recursive Feature Elimination (RFE) using Logistic Regression to select the top 3 features.

"""Expected Output:
Top 3 selected features using RFE: ['alcohol', 'flavanoids', 'od280/od315_of_diluted_wines']
"""

from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

model = LogisticRegression(max_iter=10000)
selector = RFE(model, n_features_to_select=3)
selector.fit(X, y)
top_features = X.columns[selector.get_support()].tolist()
print("Top 3 selected features using RFE: ", top_features)
# Out:
# Top 3 selected features using RFE:  ['alcohol', 'flavanoids', 'od280/od315_of_diluted_wines']

# %%
#2.
from sklearn.datasets import load_digits
import pandas as pd

X, y = load_digits(return_X_y=True, as_frame=True)

# Perform PCA for dimensionality reduction and reduce the dataset to 3 components.

'''expected output:
    
Transformed dataset (3 components):
 [[ -1.2594664   21.27488439  -9.46305689]
 [  7.9576113  -20.76870018   4.43950399]
 [  6.99192304  -9.9559863    2.95856164]
 ...
 [ 10.80128394  -6.96025023   5.59956528]
 [ -4.87210013  12.42395227 -10.17088928]
 [ -0.34438951   6.36555114  10.77371663]]
 '''

from sklearn.decomposition import PCA

pca = PCA(n_components=3, random_state=42)
X_new = pca.fit_transform(X)
print(X_new)
# Out:
# [[ -1.25946645 -21.27488348   9.46305462]
#  [  7.9576113   20.76869896  -4.43950604]
#  [  6.99192297   9.95598641  -2.95855808]
#  ...
#  [ 10.8012837    6.96025223  -5.59955453]
#  [ -4.87210009 -12.42395362  10.17086635]
#  [ -0.34438963  -6.36554919 -10.77370849]]

# %%
# 3.
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt

X, y = load_iris(return_X_y=True, as_frame=True)

# Perform t-SNE dimensionality reduction to reduce the dataset to 2 dimensions.

print(X)

from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42)
X_new = tsne.fit_transform(X)
print(X_new)

# Visualize the result
plt.scatter(X_new[:, 0], X_new[:, 1], c=y, cmap='viridis')
plt.colorbar()
plt.show()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
# [[-2.55023899e+01 -1.64392734e+00]
#  [-2.30420551e+01 -9.94582295e-01]
#  [-2.27872391e+01 -2.09691167e+00]
#  [-2.24981995e+01 -1.86189485e+00]
#  [-2.55746326e+01 -2.14822197e+00]
#  [-2.74781189e+01 -2.29930425e+00]
#  [-2.30153103e+01 -2.74105573e+00]
#  [-2.47245846e+01 -1.83705401e+00]
#  [-2.17375832e+01 -1.66233552e+00]
#  [-2.34252701e+01 -1.31013668e+00]
#  [-2.70033321e+01 -1.58407795e+00]
#  [-2.40152912e+01 -2.40064263e+00]
#  [-2.26901150e+01 -1.20087874e+00]
#  [-2.14684277e+01 -2.20239615e+00]
#  [-2.83151054e+01 -1.49631381e+00]
#  [-2.85103188e+01 -2.06727266e+00]
#  [-2.76071892e+01 -1.84780443e+00]
#  [-2.55838947e+01 -1.85156095e+00]
#  [-2.77840748e+01 -1.32479799e+00]
#  [-2.65898190e+01 -2.43044186e+00]
#  [-2.63389492e+01 -8.28937054e-01]
#  [-2.62436123e+01 -2.45074534e+00]
#  [-2.27710304e+01 -3.49606752e+00]
